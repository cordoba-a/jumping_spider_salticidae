# %% [markdown]
# ## Importación de librerias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, ImageColorGenerator
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Carga del archivo CSV

# %%
# cargar el documento csv con pd.read_csv, creando el dataframe
df = pd.read_csv('/Users/stam/Documents/Documents_MacBook_Eduardo/GitHub/jumping_spider_salticidae/datasets/salticidae_mexico_conabio.csv')

# %% [markdown]
# ## Análisis Exploratorio

# %%
# datos cargados
# muestra las primeras filas del dataframe
df.head(2)
# Out:
#                          idejemplar numcatalogo numcolecta  \
# 0  11f9827c7db57a6ad07e10ff827ab5c3        8392        NaN
# 1  82a23e1556b9ca2a7610a8b955ecf4c1        7270        NaN
#
#                                    coleccion  \
# 0  MACN-Ar Colección Nacional de Aracnología
# 1  MACN-Ar Colección Nacional de Aracnología
#
#                                          institucion paiscoleccion colector  \
# 0  MACN Museo Argentino de Ciencias Naturales Ber...     ARGENTINA      NaN
# 1  MACN Museo Argentino de Ciencias Naturales Ber...     ARGENTINA      NaN
#
#   fechacolecta  diacolecta  mescolecta  ...  usvserieIV usvserieV usvserieVI  \
# 0          NaN         NaN         NaN  ...         NaN       NaN        NaN
# 1          NaN         NaN         NaN  ...         NaN       NaN        NaN
#
#    vegetacionserenanalcms  mt24claveestadomapa  mt24nombreestadomapa  \
# 0                     NaN                  NaN                   NaN
# 1                     NaN                  NaN                   NaN
#
#   mt24clavemunicipiomapa mt24nombremunicipiomapa incertidumbreXY geoportal
# 0                    NaN                     NaN             NaN         0
# 1                    NaN                     NaN             NaN         0
#
# [2 rows x 98 columns]

# %%
# columnas del dataframe
df.columns
# Out:
# Index(['idejemplar', 'numcatalogo', 'numcolecta', 'coleccion', 'institucion',
#        'paiscoleccion', 'colector', 'fechacolecta', 'diacolecta', 'mescolecta',
#        'aniocolecta', 'determinador', 'fechadeterminacion', 'diadeterminacion',
#        'mesdeterminacion', 'aniodeterminacion', 'calificadordeterminacion',
#        'tipo', 'procedenciaejemplar', 'ejemplarfosil', 'obsusoinfo',
#        'formadecitar', 'licenciauso', 'proyecto', 'urlorigen',
#        'ultimafechaactualizacion', 'version', 'reino', 'phylumdivision',
#        'clase', 'orden', 'familia', 'genero', 'especie',
#        'categoriainfraespecie', 'categoriainfraespecie2', 'estatustax',
#        'idnombrecat', 'reftax', 'autor', 'reinovalido', 'phylumdivisionvalido',
#        'clasevalida', 'ordenvalido', 'familiavalida', 'generovalido',
#        'especievalida', 'categoriainfraespecievalida',
#        'categoriainfraespecie2valida', 'idnombrecatvalido', 'reftaxvalido',
#        'autorvalido', 'ambiente', 'categoriaresidenciaaves',
#        'formadecrecimiento', 'grupobio', 'subgrupobio', 'nombrecomun',
#        'taxonvalidado', 'taxonextinto', 'cites', 'iucn', 'nom059',
#        'prioritaria', 'nivelprioridad', 'exoticainvasora', 'endemismo',
#        'longitud', 'latitud', 'paisoriginal', 'paismapa', 'claveestadomapa',
#        'estadooriginal', 'estadomapa', 'clavemunicipiomapa',
#        'municipiooriginal', 'municipiomapa', 'localidad', 'region', 'anp',
#        'datum', 'altitudmapa', 'geovalidacion', 'regionmarinamapa',
#        'validacionambiente', 'usvserieI', 'usvserieII', 'usvserieIII',
#        'usvserieIV', 'usvserieV', 'usvserieVI', 'vegetacionserenanalcms',
#        'mt24claveestadomapa', 'mt24nombreestadomapa', 'mt24clavemunicipiomapa',
#        'mt24nombremunicipiomapa', 'incertidumbreXY', 'geoportal'],
#       dtype='object')

# %%
# identifica el tipo de datos de cada variable
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12731 entries, 0 to 12730
# Data columns (total 98 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   idejemplar                    12731 non-null  object
#  1   numcatalogo                   2810 non-null   object
#  2   numcolecta                    976 non-null    object
#  3   coleccion                     12731 non-null  object
#  4   institucion                   12731 non-null  object
#  5   paiscoleccion                 12726 non-null  object
#  6   colector                      8306 non-null   object
#  7   fechacolecta                  12352 non-null  object
#  8   diacolecta                    12352 non-null  float64
#  9   mescolecta                    12479 non-null  float64
#  10  aniocolecta                   12483 non-null  float64
#  11  determinador                  6799 non-null   object
#  12  fechadeterminacion            10319 non-null  object
#  13  diadeterminacion              10319 non-null  float64
#  14  mesdeterminacion              10412 non-null  float64
#  15  aniodeterminacion             10525 non-null  float64
#  16  calificadordeterminacion      13 non-null     object
#  17  tipo                          161 non-null    object
#  18  procedenciaejemplar           12731 non-null  object
#  19  ejemplarfosil                 6 non-null      object
#  20  obsusoinfo                    467 non-null    object
#  21  formadecitar                  12731 non-null  object
#  22  licenciauso                   9914 non-null   object
#  23  proyecto                      12731 non-null  object
#  24  urlorigen                     10803 non-null  object
#  25  ultimafechaactualizacion      12647 non-null  object
#  26  version                       12731 non-null  object
#  27  reino                         12731 non-null  object
#  28  phylumdivision                12731 non-null  object
#  29  clase                         12731 non-null  object
#  30  orden                         12731 non-null  object
#  31  familia                       12731 non-null  object
#  32  genero                        12165 non-null  object
#  33  especie                       10437 non-null  object
#  34  categoriainfraespecie         17 non-null     object
#  35  categoriainfraespecie2        0 non-null      float64
#  36  estatustax                    10292 non-null  object
#  37  idnombrecat                   12731 non-null  object
#  38  reftax                        12585 non-null  object
#  39  autor                         10292 non-null  object
#  40  reinovalido                   12565 non-null  object
#  41  phylumdivisionvalido          12565 non-null  object
#  42  clasevalida                   12565 non-null  object
#  43  ordenvalido                   12565 non-null  object
#  44  familiavalida                 12565 non-null  object
#  45  generovalido                  11999 non-null  object
#  46  especievalida                 10272 non-null  object
#  47  categoriainfraespecievalida   17 non-null     object
#  48  categoriainfraespecie2valida  0 non-null      float64
#  49  idnombrecatvalido             12565 non-null  object
#  50  reftaxvalido                  12565 non-null  object
#  51  autorvalido                   11959 non-null  object
#  52  ambiente                      11878 non-null  object
#  53  categoriaresidenciaaves       0 non-null      float64
#  54  formadecrecimiento            0 non-null      float64
#  55  grupobio                      12731 non-null  object
#  56  subgrupobio                   12731 non-null  object
#  57  nombrecomun                   14 non-null     object
#  58  taxonvalidado                 12731 non-null  object
#  59  taxonextinto                  0 non-null      float64
#  60  cites                         0 non-null      float64
#  61  iucn                          0 non-null      float64
#  62  nom059                        0 non-null      float64
#  63  prioritaria                   0 non-null      float64
#  64  nivelprioridad                0 non-null      float64
#  65  exoticainvasora               387 non-null    object
#  66  endemismo                     0 non-null      float64
#  67  longitud                      11478 non-null  float64
#  68  latitud                       11478 non-null  float64
#  69  paisoriginal                  12729 non-null  object
#  70  paismapa                      11478 non-null  object
#  71  claveestadomapa               11413 non-null  float64
#  72  estadooriginal                12580 non-null  object
#  73  estadomapa                    11413 non-null  object
#  74  clavemunicipiomapa            11413 non-null  float64
#  75  municipiooriginal             11546 non-null  object
#  76  municipiomapa                 11413 non-null  object
#  77  localidad                     12596 non-null  object
#  78  region                        12731 non-null  object
#  79  anp                           5520 non-null   object
#  80  datum                         11478 non-null  object
#  81  altitudmapa                   11400 non-null  float64
#  82  geovalidacion                 12731 non-null  object
#  83  regionmarinamapa              123 non-null    object
#  84  validacionambiente            12731 non-null  object
#  85  usvserieI                     11335 non-null  object
#  86  usvserieII                    11378 non-null  object
#  87  usvserieIII                   11379 non-null  object
#  88  usvserieIV                    11378 non-null  object
#  89  usvserieV                     11473 non-null  object
#  90  usvserieVI                    11379 non-null  object
#  91  vegetacionserenanalcms        0 non-null      float64
#  92  mt24claveestadomapa           63 non-null     float64
#  93  mt24nombreestadomapa          63 non-null     object
#  94  mt24clavemunicipiomapa        63 non-null     float64
#  95  mt24nombremunicipiomapa       63 non-null     object
#  96  incertidumbreXY               8302 non-null   float64
#  97  geoportal                     12731 non-null  int64
# dtypes: float64(26), int64(1), object(71)
# memory usage: 9.5+ MB

# %%
# dimensión del dataframe
print(f"Número de filas: {df.shape[0]}")
print(f"Número de columnas: {df.shape[1]}")
# Out:
# Número de filas: 12731
# Número de columnas: 98

# %% [markdown]
# ## Limpiesa de datos

# %%
# se verifica la completitud de las variables (valores nulos existentes)
# se utiliza la función .sum() para sumar los elementos que están vacíos (.isnull())
nulos = df.isnull().sum()

# calculo del porcentaje de completitud
completitud = pd.DataFrame(100 - (nulos / len(df) * 100))

# reset_index se utiliza para resetear los índices
# inplace = True sirve para evitar la repetición
completitud.reset_index(inplace = True)
# se coloan encebezados
completitud = completitud.rename(columns = {"index":"variable",0:"completitud"})

# ordenamos las columnas con menor completitud en adelante
completitud.sort_values(by ='completitud', ascending = True)
completitud
# Out:
#                    variable  completitud
# 0                idejemplar   100.000000
# 1               numcatalogo    22.072107
# 2                numcolecta     7.666326
# 3                 coleccion   100.000000
# 4               institucion   100.000000
# ..                      ...          ...
# 93     mt24nombreestadomapa     0.494855
# 94   mt24clavemunicipiomapa     0.494855
# 95  mt24nombremunicipiomapa     0.494855
# 96          incertidumbreXY    65.210903
# 97                geoportal   100.000000
#
# [98 rows x 2 columns]

# %%
# filtrar  arañas encontradas en México
df = df[df['paiscoleccion'].str.contains('Mexico', na=False, case=False)]

# %%
# eliminacion de los datos duplicados
df.drop_duplicates(inplace=True)

# eliminacion de los datos faltantes
df = df.dropna(subset=[ 'paiscoleccion','familiavalida','generovalido','estadooriginal'])

# .fillna reemplazará todos los valores NaN (vacíos) en la columna "especievalida" con "sp."
# .replace reemplazará las celdas vacías ("") con ".sp" en la columna "especievalida"
df['especievalida'] = df['especievalida'].fillna('sp.').replace('', 'sp.')

# las columnas con menos del 80% de completitud son eliminadas
# define una serie de pandas  con el nombre de las columnas
cols_incompletas = completitud['variable'][completitud['completitud']<80]
# se eliminan esas columnas
df = df.drop(cols_incompletas, axis=1) # 1 columnas 0 filas
df.head(2)
# Out:
#                          idejemplar                             coleccion  \
# 4  004bb44b502e17ada7daa19c1ba431e9  CNAN Colección Nacional de Arácnidos
# 5  004f14d4a5f890ddbe8284b85a091603  CNAN Colección Nacional de Arácnidos
#
#                                          institucion paiscoleccion  \
# 4  IBUNAM Instituto de Biología, Universidad Naci...        MEXICO
# 5  IBUNAM Instituto de Biología, Universidad Naci...        MEXICO
#
#   fechacolecta  diacolecta  mescolecta  aniocolecta fechadeterminacion  \
# 4   1997-03-03         3.0         3.0       1997.0                NaN
# 5   1997-12-04         4.0        12.0       1997.0                NaN
#
#    diadeterminacion  ...  altitudmapa    geovalidacion validacionambiente  \
# 4               NaN  ...          NaN  Sin coordenadas       No procesado
# 5               NaN  ...          NaN  Sin coordenadas       No procesado
#
#   usvserieI usvserieII usvserieIII usvserieIV usvserieV usvserieVI geoportal
# 4       NaN        NaN         NaN        NaN       NaN        NaN         0
# 5       NaN        NaN         NaN        NaN       NaN        NaN         0
#
# [2 rows x 66 columns]

# %%
# se verifica la completitud de las variables (valores nulos existentes)
# se utiliza la función .sum() para sumar los elementos que están vacíos (.isnull())
nulos = df.isnull().sum()

# calculo del porcentaje de completitud
completitud = pd.DataFrame(100 - (nulos / len(df) * 100))

# reset_index se utiliza para resetear los índices
# inplace = True sirve para evitar la repetición
completitud.reset_index(inplace = True)
# se coloan encebezados
completitud = completitud.rename(columns = {"index":"variable",0:"completitud"})

# ordenamos las columnas con menor completitud en adelante
completitud.sort_values(by ='completitud', ascending = True)
completitud
# Out:
#          variable  completitud
# 0      idejemplar   100.000000
# 1       coleccion   100.000000
# 2     institucion   100.000000
# 3   paiscoleccion   100.000000
# 4    fechacolecta    99.473073
# ..            ...          ...
# 61    usvserieIII    92.471198
# 62     usvserieIV    92.480129
# 63      usvserieV    92.989194
# 64     usvserieVI    92.489060
# 65      geoportal   100.000000
#
# [66 rows x 2 columns]

# %%
# dimensión del dataframe con eliminacion de datos duplicados
print(f"Número de filas: {df.shape[0]}")
print(f"Número de columnas: {df.shape[1]}")
# Out:
# Número de filas: 11197
# Número de columnas: 66

# %% [markdown]
# ## Análisis Exploratorio Posterior a la Limpieza de Datos

# %%
# word cloud
# generar el texto a partir de paiscoleccion 
text = " ".join(df['paiscoleccion'].astype(str))

# crear la nube de palabras
wordcloud = WordCloud(
    max_words=50,
    max_font_size=50,
    colormap='viridis',
    background_color="white"
).generate(text)

# configurar y mostrar el gráfico
plt.figure(figsize=(8, 4))  # establecer el tamaño de la figura
plt.imshow(wordcloud, interpolation='bilinear')  # mostrar la nube de palabras
plt.axis("off")  # ocultar ejes
plt.show()  # mostrar la figura

# %%
paiscoleccion_df = df['paiscoleccion'].value_counts()

# word cloud
# generar el texto a partir de generovalido 
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(paiscoleccion_df)

# mostrar la imagen de la nube de palabras
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # ocultar los ejes
plt.show()

# %%
familiavalida_df = df['familiavalida'].value_counts()

# word cloud
# generar el texto a partir de generovalido 
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(familiavalida_df)

# mostrar la imagen de la nube de palabras
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # ocultar los ejes
plt.show()

# %%
# word cloud
# generar el texto a partir de familiavalida 
text = " ".join(df['familiavalida'].astype(str))

# crear la nube de palabras
wordcloud = WordCloud(
    max_words=50,
    max_font_size=50,
    colormap='viridis',
    background_color="white"
).generate(text)

# configurar y mostrar el gráfico
plt.figure(figsize=(8, 4))  # establecer el tamaño de la figura
plt.imshow(wordcloud, interpolation='bilinear')  # mostrar la nube de palabras
plt.axis("off")  # ocultar ejes
plt.show()  # mostrar la figura

# %%
#¿Cómo se distribuyen las arañas por género?
# Contar el número de especies por género
generos_mas_comunes_df = df['generovalido'].value_counts()

# Mostrar los géneros más comunes
print("Géneros más comunes en México:")
print(generos_mas_comunes_df.head(10))
# Out:
# Géneros más comunes en México:
# generovalido
# Paraphidippus    2549
# Menemerus        1936
# Phidippus        1903
# Habronattus       708
# Colonus           513
# Plexippus         403
# Sassacus          381
# Messua            320
# Hasarius          232
# Lyssomanes        221
# Name: count, dtype: int64

# %%
# graficar los géneros más comunes en en mundo
generos_mas_comunes_df.head(10).plot(kind='barh', color='#FFA07A', figsize=(10, 6))
plt.title('Géneros más comunes de arañas en México', fontsize=16)
plt.xlabel('Cantidad de especies', fontsize=14)
plt.ylabel('Género', fontsize=14)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# word cloud
# generar el texto a partir de generovalido 
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(generos_mas_comunes_df)

# mostrar la imagen de la nube de palabras
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # ocultar los ejes
plt.show()

# %% [markdown]
# ## Filtrado de registros

# %% [markdown]
# ### Arañas en México y otros paises

# %% [markdown]
# ### Arañas de México
