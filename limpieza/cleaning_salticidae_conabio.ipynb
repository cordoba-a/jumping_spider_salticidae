# %% [markdown]
# ## Importación de librerias

# %%
# importamos las librerias necesarias
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Carga del archivo CSV

# %%
# cargar el documento csv con pd.read_csv, creando el dataframe
df = pd.read_csv('/Users/stam/Documents/Documents_MacBook_Eduardo/GitHub/jumping_spider_salticidae/datasets/salticidae_mexico_conabio.csv')

# %% [markdown]
# ## Limpieza de datos

# %%
# se verifica la completitud de las variables (valores nulos existentes)
# se utiliza la función .sum() para sumar los elementos que están vacíos (.isnull())
nulos = df.isnull().sum()

# calculo del porcentaje de completitud
completitud = pd.DataFrame(100 - (nulos / len(df) * 100))

# reset_index se utiliza para resetear los índices
# inplace = True sirve para evitar la repetición
completitud.reset_index(inplace = True)
# se coloan encebezados
completitud = completitud.rename(columns = {"index":"variable",0:"completitud"})

# ordenamos las columnas con mayot completitud en adelante
completitud.sort_values(by='completitud', ascending=True).head(10)
# Out:
#                         variable  completitud
# 65                        nom059          0.0
# 38        categoriainfraespecie2          0.0
# 51  categoriainfraespecie2valida          0.0
# 69                     endemismo          0.0
# 56       categoriaresidenciaaves          0.0
# 57            formadecrecimiento          0.0
# 67                nivelprioridad          0.0
# 66                   prioritaria          0.0
# 64                          iucn          0.0
# 63                         cites          0.0

# %%
# filtrar  arañas encontradas en México
df = df[df['paisoriginal'].str.contains('Mexico', na=False, case=False)]

# %%
# eliminacion de los datos duplicados
df.drop_duplicates(inplace=True)

# eliminacion de los datos faltantes
df = df.dropna(subset=[ 'paiscoleccion','familiavalida','generovalido','estadooriginal'])

# .fillna reemplazará todos los valores NaN (vacíos) en la columna "especievalida" con "sp."
# .replace reemplazará las celdas vacías ("") con ".sp" en la columna "especievalida"
df['especievalida'] = df['especievalida'].fillna('sp.').replace('', 'sp.')

# %%
# las columnas con menos del 80% de completitud son eliminadas
# define una serie de pandas  con el nombre de las columnas
cols_incompletas = completitud['variable'][completitud['completitud']<80]
# se eliminan esas columnas
df = df.drop(cols_incompletas, axis=1) # 1 columnas 0 filas
df.head(2)
# Out:
#                          idejemplar                      coleccion  \
# 0  2b8c370d2d52f42f8b330f461ac4d614  CARCIB Colección Aracnológica
# 1  72ad37ee59849904ebd0896a7ea23909        Naturalista Naturalista
#
#                                          institucion paiscoleccion  \
# 0  CIBNOR Centro de Investigaciones Biológicas de...        MEXICO
# 1  CONABIO Comisión Nacional para el Conocimiento...        MEXICO
#
#   fechacolecta  diacolecta  mescolecta  aniocolecta fechadeterminacion  \
# 0   2017-08-28        28.0         8.0       2017.0         2017-09-30
# 1   2019-08-13        13.0         8.0       2019.0         2019-08-16
#
#    diadeterminacion  ...                                      geovalidacion  \
# 0              30.0  ...                              Válido municipio 2022
# 1              16.0  ...  Válido país 2022. No aplica validación de esta...
#
#    validacionambiente                  usvserieI  \
# 0             Válido   DESPROVISTO DE VEGETACIÓN
# 1             Válido                         NaN
#
#                                           usvserieII  \
# 0                            SIN VEGETACIÓN APARENTE
# 1  AGRICULTURA DE TEMPORAL PLANTACION AGRICOLA PE...
#
#                                          usvserieIII  \
# 0                            SIN VEGETACIÓN APARENTE
# 1  AGRICULTURA DE TEMPORAL PLANTACION AGRICOLA PE...
#
#                                           usvserieIV  \
# 0                            SIN VEGETACIÓN APARENTE
# 1  AGRICULTURA DE TEMPORAL PLANTACION AGRICOLA PE...
#
#                             usvserieV                          usvserieVI  \
# 0             SIN VEGETACIÓN APARENTE             SIN VEGETACIÓN APARENTE
# 1  AGRICULTURA DE TEMPORAL PERMANENTE  AGRICULTURA DE TEMPORAL PERMANENTE
#
#                           usvserieVII geoportal
# 0             SIN VEGETACIÓN APARENTE         1
# 1  AGRICULTURA DE TEMPORAL PERMANENTE         1
#
# [2 rows x 69 columns]

# %%
# se verifica la completitud de las variables (valores nulos existentes)
# se utiliza la función .sum() para sumar los elementos que están vacíos (.isnull())
nulos = df.isnull().sum()

# calculo del porcentaje de completitud
completitud = pd.DataFrame(100 - (nulos / len(df) * 100))

# reset_index se utiliza para resetear los índices
# inplace = True sirve para evitar la repetición
completitud.reset_index(inplace = True)
# se coloan encebezados
completitud = completitud.rename(columns = {"index":"variable",0:"completitud"})

# %%
completitud.sort_values(by='completitud', ascending=True).head(60)
# Out:
#                     variable  completitud
# 26                   especie    89.439617
# 27                estatustax    89.439617
# 30                     autor    89.439617
# 8         fechadeterminacion    92.995212
# 9           diadeterminacion    92.995212
# 10          mesdeterminacion    93.607023
# 11         aniodeterminacion    94.183366
# 41                  ambiente    94.218833
# 53         municipiooriginal    94.777443
# 17                 urlorigen    95.238517
# 61                 usvserieI    98.802979
# 67               usvserieVII    99.051250
# 62                usvserieII    99.068984
# 64                usvserieIV    99.068984
# 66                usvserieVI    99.068984
# 63               usvserieIII    99.077851
# 58               altitudmapa    99.317255
# 5                 diacolecta    99.512325
# 4               fechacolecta    99.512325
# 51                estadomapa    99.592126
# 49           claveestadomapa    99.592126
# 54             municipiomapa    99.592126
# 52        clavemunicipiomapa    99.592126
# 55                 localidad    99.742862
# 7                aniocolecta    99.760596
# 6                 mescolecta    99.760596
# 40               autorvalido    99.858131
# 43               subgrupobio   100.000000
# 44             taxonvalidado   100.000000
# 42                  grupobio   100.000000
# 45                  longitud   100.000000
# 46                   latitud   100.000000
# 0                 idejemplar   100.000000
# 48                  paismapa   100.000000
# 50            estadooriginal   100.000000
# 57                     datum   100.000000
# 59             geovalidacion   100.000000
# 60        validacionambiente   100.000000
# 65                 usvserieV   100.000000
# 47              paisoriginal   100.000000
# 56                    region   100.000000
# 34               ordenvalido   100.000000
# 38         idnombrecatvalido   100.000000
# 1                  coleccion   100.000000
# 2                institucion   100.000000
# 3              paiscoleccion   100.000000
# 12       procedenciaejemplar   100.000000
# 13              formadecitar   100.000000
# 14                  proyecto   100.000000
# 15                    fuente   100.000000
# 16               urlejemplar   100.000000
# 18  ultimafechaactualizacion   100.000000
# 19                   version   100.000000
# 20                     reino   100.000000
# 39              reftaxvalido   100.000000
# 21            phylumdivision   100.000000
# 23                     orden   100.000000
# 24                   familia   100.000000
# 25                    genero   100.000000
# 28               idnombrecat   100.000000

# %%
# dimensión del dataframe con eliminacion de datos duplicados
print(f"Número de filas: {df.shape[0]}")
print(f"Número de columnas: {df.shape[1]}")
# Out:
# Número de filas: 11278
# Número de columnas: 69

# %% [markdown]
# ### Guardar dataframe en archivo CSV

# %%
# Guardar el dataframe en un archivo CSV
df.to_csv('salticidae_mexico_conabio.csv', index=False)

print("DataFrame guardado en salticidae_mexico_conabio.csv")
# Out:
# DataFrame guardado en salticidae_mexico_conabio.csv
